# %%
import pandas as pd
df2 = pd.read_csv('temp-data.csv')
# df = data[['faceId', 'question','gender', 'ethnicity','hair', 'eyes', 'trueAnswer']]
df2['question']
# Out:
# 0                               Is the person's hair long?
# 1                         does the person have a ponytail?
# 2        am I able to see the word 'new' on his shirt f...
# 3                       does her hair go past her shoulder
# 4                                      is the person male?
# 5                                      is the person male?
# 6                                                long hair
# 7         Are there at least 2 words visible on her shirt?
# 8        is the person's underneath shirt sleeves visib...
# 9                             Is this person's hair black?
# 10                                            is it a girl
# 11                                        is he dark skin?
# 12                                      is the person male
# 13                               is he wearing a necklace?
# 14                                do they have brown hair?
# 15                                             is it a boy
# ...

# %%
len(df.dropna(subset = ['question']))
# Out:
# 19144

# %%
#model = gensim.models.Word2Vec(tokens, size=15, window=5, min_count=2, workers=10, hs=1, negative=0)
model = gensim.models.Word2Vec(tokens)
model.train(tokens, total_examples=len(tokens), epochs=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-287-e8ff6593d481> in <module>()
#       1 #model = gensim.models.Word2Vec(tokens, size=15, window=5, min_count=2, workers=10, hs=1, negative=0)
# ----> 2 model = gensim.models.Word2Vec(tokens)
#       3 model.train(tokens, total_examples=len(tokens), epochs=10)
#
# NameError: name 'tokens' is not defined

# %%
model.wv.doesnt_match(["boy","girl","yes"])

# %%
model.wv.similarity(w1="boy",w2="man")

# %%
model.wv.similarity(w1="girl",w2="boy")

# %%
w1 = ["shirt"]
model.wv.most_similar (positive=w1,topn=6)

# %%
model.wv.get_vector('boy')

# %%
print(wv_model.size, wv_model.shape)

# %%
model.most_similar(['girl', 'woman'], ['boy'], topn=3)
#[('mother', 0.61849487), ('wife', 0.57972813), ('daughter', 0.56296098)]

# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import brown
import matplotlib.pyplot as plt
import gensim
import os

# %%
wpt = nltk.WordPunctTokenizer()
stop_words = nltk.corpus.stopwords.words('english')

def normalize_document(doc):
    # lower case and remove special characters\whitespaces
    doc = doc.replace("[comma]", "")
    doc = re.sub(r'[^a-zA-Z0-9\s]', '', doc, re.I|re.A)
    doc = doc.lower()
    doc = doc.strip()
    # tokenize document
    tokens = wpt.tokenize(doc)
    # filter stopwords out of document
    filtered_tokens = [token for token in tokens if token not in stop_words]
    # re-create document from filtered tokens
    doc = ' '.join(filtered_tokens)
    return doc

normalize_corpus = np.vectorize(normalize_document)

# %%
corpus = df['question']

# %%
norm_corpus = normalize_corpus(corpus)
norm_corpus
# Out:
# array(['persons hair long', 'person ponytail',
#        'able see word new shirt picture', ...,
#        'person text visible shirt', 'person red hair',
#        'person wearing glasses'], dtype='<U59')

# %%
check = pd.DataFrame(norm_corpus)

# %%
freq = pd.Series(' '.join(check[0]).split()).value_counts(1)

# %%
wpt = nltk.WordPunctTokenizer()
tokenized_corpus = [wpt.tokenize(document) for document in norm_corpus]
model = gensim.models.Word2Vec(tokenized_corpus)

# %%
c = model.wv['shirt']
print(c,c.shape, c.size)
hair = 1
b = np.concatenate(c, hair)
# Out:
# [ 0.20506631  0.11475474  0.01152693  0.05211032  0.13649894 -0.02935986
#  -0.0090216  -0.17006512 -0.2570909   0.2440725   0.24722417 -0.00663316
#  -0.21313229 -0.13772635  0.05691317  0.27173966 -0.19674632 -0.34878886
#   0.18868159 -0.02385953  0.10283452  0.3709639   0.18634775 -0.46780115
#  -0.11921148  0.13529544  0.09247528 -0.04659678 -0.03216953 -0.03552571
#   0.27582195 -0.28028482  0.04433023  0.0919531   0.1557111  -0.19076982
#  -0.51399827  0.26299086  0.25550228 -0.0897752  -0.59536356 -0.03476467
#   0.02427152  0.08885498 -0.06911715  0.05073243 -0.08961315 -0.0035862
#  -0.35201448 -0.11161352 -0.21485615  0.10334696 -0.00939129 -0.14815165
#   0.25625312  0.22408754  0.05564274 -0.03635092 -0.3617201  -0.2846553
#   0.1984718  -0.22971387 -0.15675476  0.19100264  0.16871105 -0.21738262
#  -0.4805509   0.20603554  0.00951299 -0.08431952  0.14283666  0.03609893
#   0.25071546 -0.2311734   0.04075462 -0.16050023 -0.2608891  -0.36836538
# ...

# %%
model.wv.get_vector('wet')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-296-9d2d12455715> in <module>()
# ----> 1 model.wv.get_vector('wet')
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/keyedvectors.py in get_vector(self, word)
#     275
#     276     def get_vector(self, word):
# --> 277         return self.word_vec(word)
#     278
#     279     def words_closer_than(self, w1, w2):
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     272             return result
#     273         else:
# --> 274             raise KeyError("word '%s' not in vocabulary" % word)
#     275
#     276     def get_vector(self, word):
#
# KeyError: "word 'wet' not in vocabulary"

# %%
w1 = ["boy"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('ears', 0.9990134239196777),
#  ('group', 0.9989420175552368),
#  ('old', 0.9989122748374939),
#  ('looking', 0.9988217949867249),
#  ('girl', 0.9988073110580444),
#  ('taller', 0.998786985874176)]

# %%
#sentence vectors with addition
def sentence_vectors(): 
    question_array = []
    smallList = []
    for wordList in tokenized_corpus:
        for word in wordList:
            model.wv[word]

# %%
import gensim.downloader as api

info = api.info()  # show info about available models/datasets
model = api.load("glove-twitter-25")  # download the model and return as object ready for use
model.most_similar("cat")
# Out:
# [==================================================] 100.0% 104.8/104.8MB downloaded
# [('dog', 0.9590820074081421),
#  ('monkey', 0.920357882976532),
#  ('bear', 0.914313793182373),
#  ('pet', 0.9108030796051025),
#  ('girl', 0.8880630731582642),
#  ('horse', 0.8872727155685425),
#  ('kitty', 0.8870542645454407),
#  ('puppy', 0.8867697715759277),
#  ('hot', 0.8865255117416382),
#  ('lady', 0.8845518827438354)]

# %%
from gensim.models.word2vec import Word2Vec
import gensim.downloader as api

corpus = api.load('text8')  # download the corpus and return it opened as an iterable
model = Word2Vec(corpus)  # train a model from the corpus
model.most_similar("car")
# Out:
# /Users/zeynep/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
# [('driver', 0.7900005578994751),
#  ('cars', 0.7318887710571289),
#  ('taxi', 0.7130749821662903),
#  ('motorcycle', 0.7084702253341675),
#  ('truck', 0.6938907504081726),
#  ('vehicle', 0.6836848258972168),
#  ('racing', 0.6513997316360474),
#  ('stock', 0.6306641101837158),
#  ('automobile', 0.6298074126243591),
#  ('passenger', 0.6282073259353638)]

# %%
w1 = ["shirt"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('shirts', 0.8071199655532837),
#  ('hat', 0.7532186508178711),
#  ('pants', 0.7498528957366943),
#  ('jacket', 0.7327839136123657),
#  ('nose', 0.7281990051269531),
#  ('shoes', 0.7281844019889832)]

# %%
(model.wv['long'] + model.wv['hair'])
# Out:
# array([ 4.3691945e+00,  2.6430180e+00,  3.0788777e+00, -2.5144162e+00,
#         3.9878247e+00,  3.6664138e+00, -4.6370287e+00, -1.9051857e-01,
#        -2.6335762e+00, -1.8916895e+00,  2.9355221e+00,  3.8876266e+00,
#         3.7205487e-01, -1.4924352e+00,  5.1612778e+00,  9.7089714e-01,
#         7.8680146e-01, -3.1933507e-01, -1.0556253e+00,  6.1602058e+00,
#         1.6774343e+00, -1.5107127e-01, -6.8031740e-01,  2.0317488e+00,
#        -1.6723884e+00,  1.1044294e+00,  1.0283880e+00,  4.4569400e-01,
#        -2.8019547e-03, -1.9348373e+00, -5.6792922e+00,  4.6582308e+00,
#        -1.9486704e+00, -1.3621343e+00,  4.9752712e-02, -2.8137081e+00,
#         1.7678314e-01,  1.9055103e+00, -1.9748366e+00, -4.0713215e+00,
#        -2.3674042e+00, -4.8191726e-02,  1.3262024e+00,  2.2976341e+00,
#        -1.6365857e+00,  4.5749083e+00, -7.9139411e-01, -2.4443179e-01,
#        -2.0867649e-01, -2.0581520e+00, -1.9552636e-01, -2.0595915e+00,
# ...

# %%
model.most_similar(['girl', 'woman'], ['boy'], topn=3)
# Out:
# /Users/zeynep/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('child', 0.6786067485809326),
#  ('man', 0.6560474634170532),
#  ('mother', 0.6099311709403992)]

# %%
import pandas as pd
df = pd.read_csv('temp-data.csv')

# %%
def cleanquestion(question): 
    question = re.sub(r'[^a-zA-Z0-9\s]', '', question, re.I|re.A)
    return question.replace("[comma]", "").lower().strip()

#cleaning stopwords
stopwords = ['person', 'persons', 'to','i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'because', 'as', 'until', 'while', 'into', 'through', 'during', 'off', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
normalized_stopwords = np.unique([x.replace("'", '') for x in stopwords])
#her, his, have
def removestopwords(sentence):
    newWords = []
    for word in sentence.split():
        if word not  in normalized_stopwords: 
            newWords.append(word)
    return ' '.join(newWords)

# %%
def clean_list(column):
    result = []
    for question in column:
        cleaned = cleanquestion(question)
        without_stop_words = removestopwords(cleaned)
#         print('question:%s' % question)
#         print('without_stop_words:%s' % without_stop_words)
        result.append(without_stop_words)
    return result

# %%
#making the new data frame
data = pd.read_csv("processed-data.csv")
data = data.drop(columns = ['response', 'eliminated?', 'allFaces', 'eliminatedFaces'])
data['question'] = clean_list(data['question'])
data
# Out:
#                hair        eyes trueAnswer    faceId         question  \
# 0             blond       brown        yes  IMG_9891        hair long
# 1             brown       brown        yes  IMG_0153        hair long
# 2             brown       brown         no  IMG_0446        hair long
# 3             blond        blue         no  IMG_9484        hair long
# 4             brown       brown        yes  IMG_9846        hair long
# 5             brown       brown        yes  IMG_8502        hair long
# 6             blond       hazel        yes  IMG_8198        hair long
# 7             blond       green        yes  IMG_7836        hair long
# 8             blond       brown        yes  IMG_8682        hair long
# 9             blond       brown        yes  IMG_0108        hair long
# 10            brown       brown        yes  IMG_8814        hair long
# 11       dark brown       hazel        yes  IMG_0048        hair long
# ...

# %%
subset = data[:5]
subset
# Out:
#     hair   eyes trueAnswer    faceId   question ethnicity  gender
# 0  blond  brown        yes  IMG_9891  hair long     white  female
# 1  brown  brown        yes  IMG_0153  hair long     white  female
# 2  brown  brown         no  IMG_0446  hair long     white  female
# 3  blond   blue         no  IMG_9484  hair long     white  female
# 4  brown  brown        yes  IMG_9846  hair long     white    male

# %%
counter = 0
all_rows = []
seen_vectors_by_question = {}
print('starting')
for index, item in data.iterrows():
    counter += 1
    if counter % 10000 == 0 or counter == 0:
        print('Processing %s. item' % counter)

    row      = item.get_values()
    question = row[4]

    vectors = []
    if question in seen_vectors_by_question:
        vectors = seen_vectors_by_question[question]
        if len(vectors) > 0:
            vectors = seen_vectors_by_question[question]
    else:
        for word in question.split():        
            if word in model.wv:
                if len(vectors) == 0:
                    vectors = np.array(model.wv[word])
                else:
                    vectors += np.array(model.wv[word])
    
    seen_vectors_by_question[question] = vectors
    
    if len(vectors) == 0:
        continue

    row = np.append(row, vectors)
    all_rows.append(row)

print('Done. All count %s' % len(all_rows))
# all_rows
# Out:
# starting
# Processing 10000. item
# Processing 20000. item
# Processing 30000. item
# Processing 40000. item
# Processing 50000. item
# Processing 60000. item
# Processing 70000. item
# Processing 80000. item
# Processing 90000. item
# Processing 100000. item
# Processing 110000. item
# Processing 120000. item
# Processing 130000. item
# Processing 140000. item
# Processing 150000. item
# Processing 160000. item
# Processing 170000. item
# Processing 180000. item
# Processing 190000. item
# Processing 200000. item
# Processing 210000. item
# Processing 220000. item
# Processing 230000. item
# Processing 240000. item
# Processing 250000. item
# Processing 260000. item
# Processing 270000. item
# Processing 280000. item
# Processing 290000. item
# Processing 300000. item
# Done. All count 303856

# %%
'hair' in model.wv
# Out:
# True

# %%
hair =1
# c = np.array(model.wv['hair'])
d = np.array([model.wv['brown'], model.wv['hair']])

# %%
x = model.wv['hair']
ar = np.array([1, 2])

# %%
that = ['z', 'b']

# %%
len(that)
# Out:
# 2

# %%
model.wv.get_vector('hair')
# Out:
# array([ 0.5041677 , -1.3236383 ,  1.2513157 ,  0.48900962,  1.4656291 ,
#         1.5044732 , -1.3992615 ,  0.35119796, -2.1968977 ,  1.0286535 ,
#         1.0797968 ,  2.6483145 ,  1.149075  ,  0.52415484,  2.6221666 ,
#        -0.46454078,  0.87716836,  0.40608266, -0.30319995,  0.49613285,
#         0.5163154 ,  0.12770687, -0.47401246,  0.46311587,  0.13101755,
#         0.18803087,  0.2347365 ,  0.30202675,  1.7663094 , -0.65541184,
#        -0.3835754 ,  2.1626148 , -2.1609838 , -1.1356025 , -2.160758  ,
#        -2.2684023 , -0.22101682,  1.9530358 ,  0.4076602 , -2.570698  ,
#         0.8026868 ,  0.57285243,  0.33745807,  0.32235765, -0.42158645,
#         2.5074403 , -0.6694902 , -1.034086  , -0.03382734, -0.50528836,
#        -1.1565853 ,  0.8704296 , -0.5955476 , -0.5702208 ,  0.9733583 ,
#        -2.309184  ,  0.9680028 ,  0.5007942 ,  2.6153736 , -1.6880128 ,
#         0.84262   ,  0.71160054, -1.1097388 , -0.46765867, -1.2435033 ,
# ...

# %%
#writing all_rows to csv
columns  = ['hair', 'eyes', 'true_answer', 'FaceID', 'question', 'ethnicity', 'gender']

vwList = []
for i in range(1, 101): 
    vwList.append("wv"+str(i))
columns.extend(vwList)
print(columns)
# Out:
# ['hair', 'eyes', 'true_answer', 'FaceID', 'question', 'ethnicity', 'gender', 'wv1', 'wv2', 'wv3', 'wv4', 'wv5', 'wv6', 'wv7', 'wv8', 'wv9', 'wv10', 'wv11', 'wv12', 'wv13', 'wv14', 'wv15', 'wv16', 'wv17', 'wv18', 'wv19', 'wv20', 'wv21', 'wv22', 'wv23', 'wv24', 'wv25', 'wv26', 'wv27', 'wv28', 'wv29', 'wv30', 'wv31', 'wv32', 'wv33', 'wv34', 'wv35', 'wv36', 'wv37', 'wv38', 'wv39', 'wv40', 'wv41', 'wv42', 'wv43', 'wv44', 'wv45', 'wv46', 'wv47', 'wv48', 'wv49', 'wv50', 'wv51', 'wv52', 'wv53', 'wv54', 'wv55', 'wv56', 'wv57', 'wv58', 'wv59', 'wv60', 'wv61', 'wv62', 'wv63', 'wv64', 'wv65', 'wv66', 'wv67', 'wv68', 'wv69', 'wv70', 'wv71', 'wv72', 'wv73', 'wv74', 'wv75', 'wv76', 'wv77', 'wv78', 'wv79', 'wv80', 'wv81', 'wv82', 'wv83', 'wv84', 'wv85', 'wv86', 'wv87', 'wv88', 'wv89', 'wv90', 'wv91', 'wv92', 'wv93', 'wv94', 'wv95', 'wv96', 'wv97', 'wv98', 'wv99', 'wv100']

# %%
import csv
csv_file = open("parsed_json/word2vec-data.csv", "w")

# columns = ['faceId', 'age', 'ethnicity', 'gender', 'hair', 'questions', 'responses']
csv_writer = csv.writer(csv_file)
# csv_writer.writeheader()
csv_writer.writerow(columns)
csv_writer.writerows(all_rows)

csv_file.close()

# %%
import pandas as pd
data = pd.read_csv("parsed_json/word2vec-data.csv")
data
# Out:
#                hair        eyes true_answer    FaceID         question  \
# 0             blond       brown         yes  IMG_9891        hair long
# 1             brown       brown         yes  IMG_0153        hair long
# 2             brown       brown          no  IMG_0446        hair long
# 3             blond        blue          no  IMG_9484        hair long
# 4             brown       brown         yes  IMG_9846        hair long
# 5             brown       brown         yes  IMG_8502        hair long
# 6             blond       hazel         yes  IMG_8198        hair long
# 7             blond       green         yes  IMG_7836        hair long
# 8             blond       brown         yes  IMG_8682        hair long
# 9             blond       brown         yes  IMG_0108        hair long
# 10            brown       brown         yes  IMG_8814        hair long
# 11       dark brown       hazel         yes  IMG_0048        hair long
# ...

# %% [markdown]
# # word2vec average

# %%
counter = 0
all_rows = []
seen_vectors_by_question = {}
print('starting')
for index, item in data.iterrows():
    counter += 1
    if counter % 10000 == 0 or counter == 0:
        print('Processing %s. item' % counter)

    row      = item.get_values()
    question = row[4]
    words    = question.split()

    vectors = []
    if question in seen_vectors_by_question:
        vectors_seen_before = seen_vectors_by_question[question]
        if len(vectors_seen_before) > 0:
            vectors = vectors_seen_before
    else:
        for word in words:        
            if word in model.wv:
                if len(vectors) == 0:
                    vectors = np.array(model.wv[word])
                else:
                    vectors += np.array(model.wv[word])
        seen_vectors_by_question[question] = vectors

    if len(vectors) == 0:
        # when we can't find vectors for the question
        # we skip adding it to all_rows. is that what we want?
        continue

    vectors_avg = [x / len(words) for x in vectors]

    row = np.append(row, vectors_avg)
    all_rows.append(row)

print('Done. All count %s' % len(all_rows))
# Out:
# starting
# Processing 10000. item
# Processing 20000. item
# Processing 30000. item
# Processing 40000. item
# Processing 50000. item
# Processing 60000. item
# Processing 70000. item
# Processing 80000. item
# Processing 90000. item
# Processing 100000. item
# Processing 110000. item
# Processing 120000. item
# Processing 130000. item
# Processing 140000. item
# Processing 150000. item
# Processing 160000. item
# Processing 170000. item
# Processing 180000. item
# Processing 190000. item
# Processing 200000. item
# Processing 210000. item
# Processing 220000. item
# Processing 230000. item
# Processing 240000. item
# Processing 250000. item
# Processing 260000. item
# Processing 270000. item
# Processing 280000. item
# Processing 290000. item
# Processing 300000. item
# Done. All count 303856

# %%
(all_rows[0].shape)
# Out:
# (107,)

# %%
#writing all_rows to csv
columns  = ['hair', 'eyes', 'true_answer', 'FaceID', 'question', 'ethnicity', 'gender']

vwList = []
for i in range(1, 101): 
    vwList.append("wv"+str(i))
columns.extend(vwList)
print(columns)
# Out:
# ['hair', 'eyes', 'true_answer', 'FaceID', 'question', 'ethnicity', 'gender', 'wv1', 'wv2', 'wv3', 'wv4', 'wv5', 'wv6', 'wv7', 'wv8', 'wv9', 'wv10', 'wv11', 'wv12', 'wv13', 'wv14', 'wv15', 'wv16', 'wv17', 'wv18', 'wv19', 'wv20', 'wv21', 'wv22', 'wv23', 'wv24', 'wv25', 'wv26', 'wv27', 'wv28', 'wv29', 'wv30', 'wv31', 'wv32', 'wv33', 'wv34', 'wv35', 'wv36', 'wv37', 'wv38', 'wv39', 'wv40', 'wv41', 'wv42', 'wv43', 'wv44', 'wv45', 'wv46', 'wv47', 'wv48', 'wv49', 'wv50', 'wv51', 'wv52', 'wv53', 'wv54', 'wv55', 'wv56', 'wv57', 'wv58', 'wv59', 'wv60', 'wv61', 'wv62', 'wv63', 'wv64', 'wv65', 'wv66', 'wv67', 'wv68', 'wv69', 'wv70', 'wv71', 'wv72', 'wv73', 'wv74', 'wv75', 'wv76', 'wv77', 'wv78', 'wv79', 'wv80', 'wv81', 'wv82', 'wv83', 'wv84', 'wv85', 'wv86', 'wv87', 'wv88', 'wv89', 'wv90', 'wv91', 'wv92', 'wv93', 'wv94', 'wv95', 'wv96', 'wv97', 'wv98', 'wv99', 'wv100']

# %%
import csv
csv_file = open("parsed_json/word2vec-data-2.csv", "w")

# columns = ['faceId', 'age', 'ethnicity', 'gender', 'hair', 'questions', 'responses']
csv_writer = csv.writer(csv_file)
# csv_writer.writeheader()
csv_writer.writerow(columns)
csv_writer.writerows(all_rows)

csv_file.close()
