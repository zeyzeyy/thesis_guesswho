# %%
import json
import math
data = json.load(open('parsed_json/face-rating-data-2.json'))
for (key, value) in data[0].items():
    if type(value) is dict:
        print(key, ":")
        for (key2, value2) in value.items():
            if type(value2) is dict:
                print("MORE!")
            else:
                print("  ", key2, ":", value2)

    else:
        print(key, ":", value)
# Out:
# experimentCode : guess-who-rating-task-v2
# completion_code : FMii2-#-vNw4F
# uniqueID : 85762
# demographics :
#    country : United States of America
#    gender : female
#    ethnicity-details :
#    ethnicity : white
#    age : 36
# state : finished-instructions
# trialNumber : 2
# faceID : IMG_8622
# responses :
#    non-physical-description : Is intellectual  Does a lot of reading  Not into sports accept maybe soccer  Maybe a hipster
#    physical-description : Has beautiful eyebrows and a nice hair cut. His complexion is very clean and young looking. His ears are big but who cares[comma] although people have probably made fun of him[comma] unfortunately.
#    occupation : Student or starbucks barista
#    typical : neutral
#    attractive : agree
#    photo-gender : male
#    ethnicity-details : indian
#    ethnicity : african
#    eye : brown
#    hair : black
#    age : 20

# %%
import json
import csv

json_file = open("parsed_json/face-rating-data-2.json")
json_data = json.loads(json_file.read());
json_file.close();

csv_file = open("parsed_json/face-rating-data-2.csv", "w")

headerWritten = False
for action in json_data:
    
    action['faceID'] = action['faceID']

    action['eye']  = action['responses']['eye']
    action['hair'] = action['responses']['hair']
    action['age'] = action['responses']['age']
    action['gender'] = action['responses']['photo-gender']
    if 'ethnicity' in action['responses']:
        action['ethnicity'] = action['responses']['ethnicity']
    else: 
        action['ethnicity'] = None

    action.pop('experimentCode')
    action.pop('completion_code')
    action.pop('uniqueID')
    action.pop('demographics')
    action.pop('state')
    action.pop('trialNumber')
    action.pop('responses')
    
    columns    = sorted(action.keys())
    csv_writer = csv.DictWriter(csv_file, columns)

    if not headerWritten:
        csv_writer.writeheader()
        headerWritten = True

    csv_writer.writerow(action);

csv_file.close();

print('done!')
# Out:
# done!

# %%
import pandas as pd
df = pd.DataFrame.from_csv('parsed_json/face-rating-data-2.csv', index_col = None)

by_image = {}
for index, item in df.iterrows():
    if not item['faceID'] in by_image:
        by_image[item['faceID']] = item


print(by_image)
# Out:
# /Users/zeynep/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
# {'IMG_8622': age                20
# ethnicity     african
# eye             brown
# faceID       IMG_8622
# gender           male
# hair            black
# Name: 0, dtype: object, 'IMG_7942': age                24
# ethnicity       white
# eye             brown
# faceID       IMG_7942
# gender           male
# hair            black
# Name: 1, dtype: object, 'IMG_0401': age                25
# ethnicity     african
# eye             black
# faceID       IMG_0401
# gender           male
# hair            black
# Name: 2, dtype: object, 'IMG_0018': age                23
# ethnicity       white
# eye              Blue
# faceID       IMG_0018
# gender           male
# hair           Blonde
# ...

# %%
import pandas as pd
df = pd.DataFrame.from_csv('parsed_json/face-rating-data-2.csv', index_col = None)
df
# Out:
# /Users/zeynep/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#      age ethnicity         eye    faceID  gender           hair
# 0     20   african       brown  IMG_8622    male          black
# 1     24     white       brown  IMG_7942    male          black
# 2     25   african       black  IMG_0401    male          black
# 3     23     white        Blue  IMG_0018    male         Blonde
# 4     26     white       brown  IMG_0777    male          brown
# 5     23     white       green  IMG_9153  female          brown
# 6     20     white       brown  IMG_8153  female         blonde
# 7     45     white       green  IMG_9861  female          black
# 8     32   african       Black  IMG_7882    male          Black
# ...
